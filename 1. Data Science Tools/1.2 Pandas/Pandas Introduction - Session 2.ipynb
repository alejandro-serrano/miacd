# %%
import numpy as np
import pandas as pd

# %%
DF = pd.read_csv('celebrity_deaths_2016.csv')

# %%
DF
# Out:
#      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
DF.describe()
# Out:
#        dateofdeath        name   age                   bio causeofdeath  \
# count         6543        6543  6516                  6541         1535
# unique         364        6526   138                  5886          361
# top     2016-11-28  Jack Riley    86  American politician.       cancer
# freq            43           2   236                    33          248
#
#                         Unnamed: 5 Unnamed: 6
# count                            1          1
# unique                           1          1
# top      neuroendocrine carcinoma.
# freq                             1          1

# %%
DF.head(10)
# Out:
#   dateofdeath                name age  \
# 0  2016-01-01           Tony Lane  71
# 1  2016-01-01      Gilbert Kaplan  74
# 2  2016-01-01         Brian Johns  79
# 3  2016-01-01     Natasha Aguilar  45
# 4  2016-01-01        Fazu Aliyeva  83
# 5  2016-01-01          Mike Oxley  71
# 6  2016-01-01  John Coleman Moore  92
# 7  2016-01-01        Jacques Deny  99
# 8  2016-01-01              Mark B  45
# 9  2016-01-01    George Alexandru  58
#
#                                                  bio  \
# 0              American art director (Rolling Stone)
# 1                 American conductor and businessman
# 2  Australian company director, managing director...
# 3  Costa Rican swimmer, silver and bronze medalis...
# 4                   Russian Avar poet and journalist
# 5  American politician, member of the United Stat...
# 6                            American mathematician.
# 7                              French mathematician.
# 8                   British hip-hop record producer.
# ...

# %%
DF.tail(3)
# Out:
#      dateofdeath                      name age  \
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio causeofdeath  \
# 6540  Sri Lankan politician, Prime Minister (2000200...          NaN
# 6541  American racehorse (death announced on this date)   euthanized
# 6542                                 Indian politician.          NaN
#
#      Unnamed: 5 Unnamed: 6
# 6540        NaN        NaN
# 6541        NaN        NaN
# 6542        NaN        NaN

# %%
DF.sample(n=5)
# Out:
#      dateofdeath               name age  \
# 5412  2016-10-24    Reinhard Hfner  64
# 6484  2016-12-26  Kalinik of Vratsa  85
# 3511  2016-07-03     Jimmy Frizzell  79
# 1242  2016-03-02      Roger Hickman  61
# 6459  2016-12-25     Anton Gubankov  51
#
#                                                     bio   causeofdeath  \
# 5412  German footballer (Dynamo Dresden), Olympic ch...            NaN
# 6484  Bulgarian Orthodox prelate, Metropolitan of Vr...            NaN
# 3511              Scottish football player and manager.            NaN
# 1242  Australian yachtsman, winner of the Sydney to ...   brain cancer
# 6459  Notable Russian people killed in the crash of ...            NaN
#
#      Unnamed: 5 Unnamed: 6
# 5412        NaN        NaN
# 6484        NaN        NaN
# 3511        NaN        NaN
# 1242        NaN        NaN
# 6459        NaN        NaN

# %%
DF['name']
# Out:
# 0                      Tony Lane
# 1                 Gilbert Kaplan
# 2                    Brian Johns
# 3                Natasha Aguilar
# 4                   Fazu Aliyeva
#                   ...
# 6538             Barbara Tarbuck
# 6539              Hans Tietmeyer
# 6540    Ratnasiri Wickremanayake
# 6541                Cara Rafaela
# 6542       Balasaheb Vikhe Patil
# Name: name, Length: 6543, dtype: object

# %%
DF.keys
# Out:
# <bound method NDFrame.keys of      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
DF['age'][5]
# Out:
# '71'

# %%
DF['name'][5]
# Out:
# 'Mike Oxley'

# %%
DF.loc[8:12,'name':'bio']
# Out:
#                 name age                                                bio
# 8             Mark B  45                   British hip-hop record producer.
# 9   George Alexandru  58                   Romanian theater and film actor.
# 10    Anil Salgaocar  75                   Indian executive and politician.
# 11       Homa Nategh  80                    Iranian educator and historian.
# 12        Ian Pieris  82  Sri Lankan cricketer (Cambridge University Cri...

# %%
DF.iloc[800:810, 0:2]
# Out:
#     dateofdeath                   name
# 800  2016-02-08         Violette Verdy
# 801  2016-02-08       Samuel Rappaport
# 802  2016-02-08            John Disley
# 803  2016-02-08  William Donald Stiehl
# 804  2016-02-08          Johnny Duncan
# 805  2016-02-08        Leon Vilaincour
# 806  2016-02-08            Viggo Rivad
# 807  2016-02-08           Norman Hudis
# 808  2016-02-08    August P. Mardesich
# 809  2016-02-08           Amelia Bence

# %%
DF.at[2, 'age']
# Out:
# '79'

# %%
DF.drop(columns = ['Unnamed: 5','Unnamed: 6'])
# Out:
#      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
DF.drop(columns = ['Unnamed: 5','Unnamed: 6'], inplace=True)
DF.columns
# Out:
# Index(['dateofdeath', 'name', 'age', 'bio', 'causeofdeath'], dtype='object')

# %%
DF
# Out:
#      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
DF.drop(columns = ['age'])
# Out:
#      dateofdeath                      name  \
# 0     2016-01-01                 Tony Lane
# 1     2016-01-01            Gilbert Kaplan
# 2     2016-01-01               Brian Johns
# 3     2016-01-01           Natasha Aguilar
# 4     2016-01-01              Fazu Aliyeva
# ...          ...                       ...
# 6538  2016-12-27           Barbara Tarbuck
# 6539  2016-12-27            Hans Tietmeyer
# 6540  2016-12-27  Ratnasiri Wickremanayake
# 6541  2016-12-27              Cara Rafaela
# 6542  2016-12-27     Balasaheb Vikhe Patil
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...                                                 ...
# ...

# %%
DF.drop(index = [0,1])
# Out:
#      dateofdeath                      name age  \
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# 5     2016-01-01                Mike Oxley  71
# 6     2016-01-01        John Coleman Moore  92
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# 5     American politician, member of the United Stat...
# 6                               American mathematician.
# ...

# %%
DF [DF['name']== 'Mark B']
# Out:
#   dateofdeath    name age                               bio causeofdeath
# 8  2016-01-01  Mark B  45  British hip-hop record producer.          NaN

# %%
pd.unique(DF['age'])
# Out:
# array(['71', '74', '79', '45', '83', '92', '99', '58', '75', '80', '82',
#        '85', '89', '90', '93', '96', '87', '91', '38', '56', '22', '62',
#        '84', '51', '33', '37', '69', '86', '97', '67', '95', '70', '63',
#        '81', '54', '73', '66', '76', '88', '28', '31', '102', '68', '77',
#        '94', '64', '32', '59', '47', '100', '23', ' 8889', '65', '72',
#        '60', '48', '57', '78', '26', '61', '103', '98', '25', '20', '101',
#        '40', '44', '14', '53', '112', '43', '21', '55', '16', '15', '52',
#        nan, '34', '49', '50', '35', '11', '24', '41', ' 4445', '12', '30',
#        '42', ' 5253', '39', '107', ' 6869', '46', ' 3031', '36', '104',
#        ' 6768', ' 6364', '27', '29', ' 5759', ' 9293', '19', ' 3435',
#        ' 7677', ' 2526', ' 68-69', ' 7980', ' 9192', '110', ' 2930', '17',
#        ' 8081', ' 9394', '116', ' 7374', ' c. 48', '9', '113', ' 51-52',
#        ' c._180', '109', ' 4243', '106', ' 61/62', ' 6667', ' 77/78',
# ...

# %%
DF.nunique()
# Out:
# dateofdeath      364
# name            6526
# age              138
# bio             5886
# causeofdeath     361
# dtype: int64

# %%
DF.index
# Out:
# RangeIndex(start=0, stop=6543, step=1)

# %%
DF2 = DF.copy()

# %%
DF2['age'] = pd.to_numeric(DF['age'], errors = 'coerce')
pd.unique(DF2['age'])
# Out:
# array([7.100e+01, 7.400e+01, 7.900e+01, 4.500e+01, 8.300e+01, 9.200e+01,
#        9.900e+01, 5.800e+01, 7.500e+01, 8.000e+01, 8.200e+01, 8.500e+01,
#        8.900e+01, 9.000e+01, 9.300e+01, 9.600e+01, 8.700e+01, 9.100e+01,
#        3.800e+01, 5.600e+01, 2.200e+01, 6.200e+01, 8.400e+01, 5.100e+01,
#        3.300e+01, 3.700e+01, 6.900e+01, 8.600e+01, 9.700e+01, 6.700e+01,
#        9.500e+01, 7.000e+01, 6.300e+01, 8.100e+01, 5.400e+01, 7.300e+01,
#        6.600e+01, 7.600e+01, 8.800e+01, 2.800e+01, 3.100e+01, 1.020e+02,
#        6.800e+01, 7.700e+01, 9.400e+01, 6.400e+01, 3.200e+01, 5.900e+01,
#        4.700e+01, 1.000e+02, 2.300e+01, 8.889e+03, 6.500e+01, 7.200e+01,
#        6.000e+01, 4.800e+01, 5.700e+01, 7.800e+01, 2.600e+01, 6.100e+01,
#        1.030e+02, 9.800e+01, 2.500e+01, 2.000e+01, 1.010e+02, 4.000e+01,
#        4.400e+01, 1.400e+01, 5.300e+01, 1.120e+02, 4.300e+01, 2.100e+01,
#        5.500e+01, 1.600e+01, 1.500e+01, 5.200e+01,       nan, 3.400e+01,
# ...

# %%
DF2.nlargest(10, columns=['age'])
# Out:
#      dateofdeath                            name     age  \
# 2595  2016-05-11               Abdul Baqi Jammoh  9394.0
# 1807  2016-03-29                    Zafar Mahmud  9293.0
# 2408  2016-05-01                   Hamzat Ahmadu  9192.0
# 149   2016-01-07                Patrick Connolly  8889.0
# 4642  2016-09-07                  Farhang Sharif  8485.0
# 5698  2016-11-11  Turki II bin Abdulaziz Al Saud  8182.0
# 2594  2016-05-11                  Majid al-Shibl  8081.0
# 2198  2016-04-18                    Marwan Dudin  7980.0
# 5697  2016-11-11                  Muhammad Surur  7778.0
# 2014  2016-04-08                 Nicola Abu Raed  7677.0
#
#                                                     bio causeofdeath
# 2595           Jordanian politician, Senator (19972001)          NaN
# 1807                                     Indian pilot.           NaN
# 2408  Nigerian diplomat, Ambassador to the Soviet Un...          NaN
# ...

# %%
DF.size
# Out:
# 32715

# %% [markdown]
# #### -----------------------------

# %%
DF = pd.read_csv('celebrity_deaths_2016.csv')
# Average number of celebrities who died between February and July 2019

# %%
DF
# Out:
#      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
DF['Unnamed: 6'].unique()
# Out:
# array([nan, ' '], dtype=object)

# %%
DF.drop(['Unnamed: 6'], axis = 1, inplace=True)

# %%
DF
# Out:
#      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
DF['Unnamed: 5'].unique()
# Out:
# array([nan, ' neuroendocrine carcinoma.'], dtype=object)

# %%
DF[DF['Unnamed: 5'] == ' neuroendocrine carcinoma.']
# Out:
#      dateofdeath             name age                                     bio  \
# 6461  2016-12-25  Alphonse Mouzon  68   American jazz drummer (Weather Report
#
#                                      causeofdeath                  Unnamed: 5
# 6461   The Eleventh House) and record label owner   neuroendocrine carcinoma.

# %%
DF.iloc[6461,3] = DF.iloc[6461,3] + DF.iloc[6461,4]
DF.iloc[6461,4] = DF.iloc[6461,5]

# %%
DF[DF['Unnamed: 5'] == ' neuroendocrine carcinoma.']
# Out:
#      dateofdeath             name age  \
# 6461  2016-12-25  Alphonse Mouzon  68
#
#                                                     bio  \
# 6461   American jazz drummer (Weather Report The Ele...
#
#                     causeofdeath                  Unnamed: 5
# 6461   neuroendocrine carcinoma.   neuroendocrine carcinoma.

# %%
DF.drop(['Unnamed: 5'], axis = 1, inplace=True)

# %%
DF['causeofdeath'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6538     True
# 6539     True
# 6540     True
# 6541    False
# 6542     True
# Name: causeofdeath, Length: 6543, dtype: bool

# %%
X = DF['causeofdeath'].unique()
# X.sort(axis=0)
print(X.shape)
# Out:
# (362,)

# %%
Y = DF['causeofdeath'].value_counts()
Y
# Out:
# causeofdeath
#  cancer                                                248
#  heart attack                                          125
#  traffic collision                                      56
#  lung cancer                                            51
#  pneumonia                                              50
#                                                       ...
#  complications from accident                             1
#  septic shock                                            1
#  grenade explosion                                       1
#  complications from esophageal cancer and pneumonia      1
# euthanized                                               1
# Name: count, Length: 361, dtype: int64

# %%
DF['causeofdeath'] = DF['causeofdeath'].str.strip()

# %%
Y = DF['causeofdeath'].value_counts()
Y
# Out:
# causeofdeath
# cancer                         257
# heart attack                   135
# traffic collision               57
# lung cancer                     52
# pneumonia                       51
#                               ...
# plasma cell leukemia             1
# non-Hodgkin lymphoma             1
# complications from accident      1
# septic shock                     1
# euthanized                       1
# Name: count, Length: 326, dtype: int64

# %%
X = DF['causeofdeath'].unique()
X.sort(axis=0)
X

# %%
A = ['anthropologist and ethnologist', 'anti-smoking campaigner', 'Bharatiya Janta Party leader','Birmingham City)', 'Bordertown)', 'Boston Braves)','Carlisle United)', 'Celtic)','Dutch-born Indonesian Roman Catholic prelate, Bishop of Amboina (19651994)', "Environment and National Service minister and MP for St Ann's East", 'Bharatiya Janta Party leader', 'Myself and I)', 'Star Trek)', 'Tony winner (1970)','choreographer and instructor']
A
# Out:
# ['anthropologist and ethnologist',
#  'anti-smoking campaigner',
#  'Bharatiya Janta Party leader',
#  'Birmingham City)',
#  'Bordertown)',
#  'Boston Braves)',
#  'Carlisle United)',
#  'Celtic)',
#  'Dutch-born Indonesian Roman Catholic prelate, Bishop of Amboina (19651994)',
#  "Environment and National Service minister and MP for St Ann's East",
#  'Bharatiya Janta Party leader',
#  'Myself and I)',
#  'Star Trek)',
#  'Tony winner (1970)',
#  'choreographer and instructor']

# %%
X = DF[ DF['causeofdeath'].isin(A)].index
X
# Out:
# Index([ 441,  463, 1530, 1739, 3096, 4071, 4592, 4755, 5081, 5504, 5751, 5937,
#        6045, 6073],
#       dtype='int64')

# %%
DF.iloc[X,:]
# Out:
#      dateofdeath                         name  age  \
# 441   2016-01-21           Mrinalini Sarabhai   97
# 463   2016-01-22                   John Dowie   60
# 1530  2016-03-15                Lincoln Myers   66
# 1739  2016-03-26  Andreas Peter Cornelius Sol  100
# 3096  2016-06-10                   Alex Govan   86
# 4071  2016-08-05                    Joe Davis   75
# 4592  2016-09-05                     Arif Beg   81
# 4755  2016-09-16                  Hagan Beggs   79
# 5081  2016-10-05            Georges Balandier   95
# 5504  2016-10-30                 Don Marshall   80
# 5751  2016-11-15                    Bob Addis   91
# 5937  2016-11-26                 Fritz Weaver   90
# 6045  2016-12-01                    Don Calfa   76
# 6073  2016-12-03                Sir David Hay   88
#
#                                                     bio  \
# 441                             Indian classical dancer
# 463                         Scottish footballer (Fulham
# ...

# %%
DF['bio'][X] = DF['bio'][X] + " " + DF['causeofdeath'][X]
DF.iloc[X,:]
# Out:
# /var/folders/f3/_st5g9tj5bs69f2k8ttz8mwh0000gn/T/ipykernel_99847/1266251826.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   DF['bio'][X] = DF['bio'][X] + " " + DF['causeofdeath'][X]
# ...

# %%
DF['causeofdeath'][X] = 'unknown'
# Out:
# /var/folders/f3/_st5g9tj5bs69f2k8ttz8mwh0000gn/T/ipykernel_99847/434743244.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   DF['causeofdeath'][X] = 'unknown'

# %%
DF['causeofdeath']
# Out:
# 0                    brain cancer
# 1                          cancer
# 2                          cancer
# 3       complications of a stroke
# 4                   heart failure
#                   ...
# 6538                          NaN
# 6539                          NaN
# 6540                          NaN
# 6541                   euthanized
# 6542                          NaN
# Name: causeofdeath, Length: 6543, dtype: object

# %%
DF.loc[X,'bio'] = DF['bio'][X]+" " + DF['causeofdeath'][X]
DF.iloc[X,:]
# Out:
#      dateofdeath                         name  age  \
# 441   2016-01-21           Mrinalini Sarabhai   97
# 463   2016-01-22                   John Dowie   60
# 1530  2016-03-15                Lincoln Myers   66
# 1739  2016-03-26  Andreas Peter Cornelius Sol  100
# 3096  2016-06-10                   Alex Govan   86
# 4071  2016-08-05                    Joe Davis   75
# 4592  2016-09-05                     Arif Beg   81
# 4755  2016-09-16                  Hagan Beggs   79
# 5081  2016-10-05            Georges Balandier   95
# 5504  2016-10-30                 Don Marshall   80
# 5751  2016-11-15                    Bob Addis   91
# 5937  2016-11-26                 Fritz Weaver   90
# 6045  2016-12-01                    Don Calfa   76
# 6073  2016-12-03                Sir David Hay   88
#
#                                                     bio causeofdeath
# 441   Indian classical dancer choreographer and inst...      unknown
# ...

# %%
DF.loc[X, 'causeofdeath'] = 'unknown'
DF.iloc[X,:]
# Out:
#      dateofdeath                         name  age  \
# 441   2016-01-21           Mrinalini Sarabhai   97
# 463   2016-01-22                   John Dowie   60
# 1530  2016-03-15                Lincoln Myers   66
# 1739  2016-03-26  Andreas Peter Cornelius Sol  100
# 3096  2016-06-10                   Alex Govan   86
# 4071  2016-08-05                    Joe Davis   75
# 4592  2016-09-05                     Arif Beg   81
# 4755  2016-09-16                  Hagan Beggs   79
# 5081  2016-10-05            Georges Balandier   95
# 5504  2016-10-30                 Don Marshall   80
# 5751  2016-11-15                    Bob Addis   91
# 5937  2016-11-26                 Fritz Weaver   90
# 6045  2016-12-01                    Don Calfa   76
# 6073  2016-12-03                Sir David Hay   88
#
#                                                     bio causeofdeath
# 441   Indian classical dancer choreographer and inst...      unknown
# ...

# %%
DF2 = DF.copy()

# %%
DF['dateofdeath']
# Out:
# 0       2016-01-01
# 1       2016-01-01
# 2       2016-01-01
# 3       2016-01-01
# 4       2016-01-01
#            ...
# 6538    2016-12-27
# 6539    2016-12-27
# 6540    2016-12-27
# 6541    2016-12-27
# 6542    2016-12-27
# Name: dateofdeath, Length: 6543, dtype: object

# %%
DF2['month'] = DF2['dateofdeath'].str.split('-')
DF2['month'] = DF2['month'].str.get(1)
DF2['month'] = DF2['month'].astype(int)
DF2['month']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 6538    12
# 6539    12
# 6540    12
# 6541    12
# 6542    12
# Name: month, Length: 6543, dtype: int64

# %%
DF
# Out:
#      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
DF2
# Out:
#      dateofdeath                      name age  \
# 0     2016-01-01                 Tony Lane  71
# 1     2016-01-01            Gilbert Kaplan  74
# 2     2016-01-01               Brian Johns  79
# 3     2016-01-01           Natasha Aguilar  45
# 4     2016-01-01              Fazu Aliyeva  83
# ...          ...                       ...  ..
# 6538  2016-12-27           Barbara Tarbuck  74
# 6539  2016-12-27            Hans Tietmeyer  85
# 6540  2016-12-27  Ratnasiri Wickremanayake  83
# 6541  2016-12-27              Cara Rafaela  23
# 6542  2016-12-27     Balasaheb Vikhe Patil  84
#
#                                                     bio  \
# 0                 American art director (Rolling Stone)
# 1                    American conductor and businessman
# 2     Australian company director, managing director...
# 3     Costa Rican swimmer, silver and bronze medalis...
# 4                      Russian Avar poet and journalist
# ...

# %%
X = DF2['age'].str.isdigit()
X
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6538    True
# 6539    True
# 6540    True
# 6541    True
# 6542    True
# Name: age, Length: 6542, dtype: object

# %%
I = X == False
I
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6538    False
# 6539    False
# 6540    False
# 6541    False
# 6542    False
# Name: age, Length: 6542, dtype: bool

# %%
DF2[I]
# Out:
#      dateofdeath                            name        age  \
# 149   2016-01-07                Patrick Connolly       8889
# 810   2016-02-08                  Sikiru Adesina       4445
# 946   2016-02-15        Abdul Rahman Al-Hanaqtah       5253
# 1043  2016-02-20                     Dave Needle       6869
# 1224  2016-02-29                    Mumtaz Qadri       3031
# 1491  2016-03-12                  Richard Fowler       6768
# 1628  2016-03-19           Zeinab Elobeid Yousif       6364
# 1718  2016-03-25               Abu Ali al-Anbari       5759
# 1807  2016-03-29                    Zafar Mahmud       9293
# 1892  2016-04-02                    Samid Imanov       3435
# 2014  2016-04-08                 Nicola Abu Raed       7677
# 2057  2016-04-11              Mohsen Gheytaslou,       2526
# 2080  2016-04-12                  Robbie Brennan      68-69
# 2198  2016-04-18                    Marwan Dudin       7980
# 2408  2016-05-01                   Hamzat Ahmadu       9192
# ...

# %%
DF2.at[5343,'age'] = str(55)
DF2.at[5343,'age']
# Out:
# '55'

# %%
DF2 = DF2.drop(index=[3844])

# %%
X = DF2['age'].str.isdigit()
X
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6538    True
# 6539    True
# 6540    True
# 6541    True
# 6542    True
# Name: age, Length: 6542, dtype: object

# %%
DF2[I]
# Out:
#      dateofdeath                            name        age  \
# 149   2016-01-07                Patrick Connolly       8889
# 810   2016-02-08                  Sikiru Adesina       4445
# 946   2016-02-15        Abdul Rahman Al-Hanaqtah       5253
# 1043  2016-02-20                     Dave Needle       6869
# 1224  2016-02-29                    Mumtaz Qadri       3031
# 1491  2016-03-12                  Richard Fowler       6768
# 1628  2016-03-19           Zeinab Elobeid Yousif       6364
# 1718  2016-03-25               Abu Ali al-Anbari       5759
# 1807  2016-03-29                    Zafar Mahmud       9293
# 1892  2016-04-02                    Samid Imanov       3435
# 2014  2016-04-08                 Nicola Abu Raed       7677
# 2057  2016-04-11              Mohsen Gheytaslou,       2526
# 2080  2016-04-12                  Robbie Brennan      68-69
# 2198  2016-04-18                    Marwan Dudin       7980
# 2408  2016-05-01                   Hamzat Ahmadu       9192
# ...

# %%
DF2.loc[I, 'age'] = DF2.loc[I, 'age'].apply(lambda s: s[-2:])

# %%
DF2[I]
# Out:
#      dateofdeath                            name age  \
# 149   2016-01-07                Patrick Connolly  89
# 810   2016-02-08                  Sikiru Adesina  45
# 946   2016-02-15        Abdul Rahman Al-Hanaqtah  53
# 1043  2016-02-20                     Dave Needle  69
# 1224  2016-02-29                    Mumtaz Qadri  31
# 1491  2016-03-12                  Richard Fowler  68
# 1628  2016-03-19           Zeinab Elobeid Yousif  64
# 1718  2016-03-25               Abu Ali al-Anbari  59
# 1807  2016-03-29                    Zafar Mahmud  93
# 1892  2016-04-02                    Samid Imanov  35
# 2014  2016-04-08                 Nicola Abu Raed  77
# 2057  2016-04-11              Mohsen Gheytaslou,  26
# 2080  2016-04-12                  Robbie Brennan  69
# 2198  2016-04-18                    Marwan Dudin  80
# 2408  2016-05-01                   Hamzat Ahmadu  92
# 2515  2016-05-06                      Abu Waheeb  30
# 2594  2016-05-11                  Majid al-Shibl  81
# ...

# %%
DF2.loc[I,'age'].str.isdigit().all()
# Out:
# True

# %%
print(DF2['age'].unique())
# Out:
# ['71' '74' '79' '45' '83' '92' '99' '58' '75' '80' '82' '85' '89' '90'
#  '93' '96' '87' '91' '38' '56' '22' '62' '84' '51' '33' '37' '69' '86'
#  '97' '67' '95' '70' '63' '81' '54' '73' '66' '76' '88' '28' '31' '102'
#  '68' '77' '94' '64' '32' '59' '47' '100' '23' '65' '72' '60' '48' '57'
#  '78' '26' '61' '103' '98' '25' '20' '101' '40' '44' '14' '53' '112' '43'
#  '21' '55' '16' '15' '52' nan '34' '49' '50' '35' '11' '24' '41' '12' '30'
#  '42' '39' '107' '46' '36' '104' '27' '29' '19' '110' '17' '116' '9' '113'
#  '109' '106' '18' '7' '105' '108']

# %%
ind = DF2['age'].isnull()
ind
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6538    False
# 6539    False
# 6540    False
# 6541    False
# 6542    False
# Name: age, Length: 6542, dtype: bool

# %%
ind.all()
# Out:
# False

# %%
ind = ind[ind == True]
ind
# Out:
# 496     True
# 553     True
# 648     True
# 827     True
# 947     True
# 1350    True
# 1738    True
# 1898    True
# 1959    True
# 2058    True
# 2251    True
# 2580    True
# 2715    True
# 2802    True
# 3239    True
# 3320    True
# 3574    True
# 3634    True
# 4457    True
# 4954    True
# 5094    True
# 5108    True
# 5288    True
# 5699    True
# 6008    True
# 6391    True
# 6430    True
# Name: age, dtype: bool

# %%
DF2 = DF2.drop(ind.index)

# %%
print(DF2['age'].unique())
# Out:
# ['71' '74' '79' '45' '83' '92' '99' '58' '75' '80' '82' '85' '89' '90'
#  '93' '96' '87' '91' '38' '56' '22' '62' '84' '51' '33' '37' '69' '86'
#  '97' '67' '95' '70' '63' '81' '54' '73' '66' '76' '88' '28' '31' '102'
#  '68' '77' '94' '64' '32' '59' '47' '100' '23' '65' '72' '60' '48' '57'
#  '78' '26' '61' '103' '98' '25' '20' '101' '40' '44' '14' '53' '112' '43'
#  '21' '55' '16' '15' '52' '34' '49' '50' '35' '11' '24' '41' '12' '30'
#  '42' '39' '107' '46' '36' '104' '27' '29' '19' '110' '17' '116' '9' '113'
#  '109' '106' '18' '7' '105' '108']

# %%
DF2.loc[:, 'age'].isnull().any()
# Out:
# False

# %%
DF2['age'] = pd.to_numeric(DF2['age'], errors='raise')

# %%
DF2.describe()
# Out:
#                age        month
# count  6515.000000  6515.000000
# mean     76.947813     6.239140
# std      16.472175     3.489302
# min       7.000000     1.000000
# 25%      69.000000     3.000000
# 50%      81.000000     6.000000
# 75%      89.000000     9.000000
# max     116.000000    12.000000

# %%
I = (DF2['month'] >= 2) & (DF2['month'] <= 7) 
DF2.loc[I, 'age'].describe()
# Out:
# count    3325.000000
# mean       77.077293
# std        16.374244
# min         9.000000
# 25%        69.000000
# 50%        81.000000
# 75%        89.000000
# max       116.000000
# Name: age, dtype: float64

# %% [markdown]
# #### -----------------------------

# %% [markdown]
# ## Data operators

# %%
A = pd.Series([2,4,6], index = [0,1,2])
B = pd.Series([5,7,9], index = [1,2,3])
print(A,'\n\n',B)
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64
#
#  1    5
# 2    7
# 3    9
# dtype: int64

# %%
A+B
# Out:
# 0     NaN
# 1     9.0
# 2    13.0
# 3     NaN
# dtype: float64

# %%
A.add(B, fill_value = 0)
# Out:
# 0     2.0
# 1     9.0
# 2    13.0
# 3     9.0
# dtype: float64

# %%
rng = np.random.RandomState(24)
A = pd.DataFrame(rng.randint(0,20,(2,2)), columns = list('AB'))
A
# Out:
#    A   B
# 0  2   3
# 1  0  17

# %%
B = pd.DataFrame(rng.randint(0,10,(3,3)), columns = list('BAC'))
B
# Out:
#    B  A  C
# 0  1  1  4
# 1  4  3  2
# 2  3  3  7

# %%
C = A+B
C
# Out:
#      A     B   C
# 0  3.0   4.0 NaN
# 1  3.0  21.0 NaN
# 2  NaN   NaN NaN

# %%
print(None, float('nan'),np.nan)
# Out:
# None nan nan

# %%
C.notnull()
# Out:
#        A      B      C
# 0   True   True  False
# 1   True   True  False
# 2  False  False  False

# %%
C.isnull()
# Out:
#        A      B     C
# 0  False  False  True
# 1  False  False  True
# 2   True   True  True

# %%
data = pd.Series([1,np.nan,'hello',None])
data[ data.notnull()]
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
df = pd.DataFrame([[1, None, 2], [4,5,7], [np.nan, 4, 2]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  4.0  5.0  7
# 2  NaN  4.0  2

# %%
df.dropna()
# Out:
#      0    1  2
# 1  4.0  5.0  7

# %%
df.dropna(axis=1)
# Out:
#    2
# 0  2
# 1  7
# 2  2

# %%
df[3] = np.nan
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  4.0  5.0  7 NaN
# 2  NaN  4.0  2 NaN

# %%
df.dropna(axis = 'columns', how = 'all')
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  4.0  5.0  7
# 2  NaN  4.0  2

# %%
df.dropna(axis = 'rows', thresh = 3)
# Out:
#      0    1  2   3
# 1  4.0  5.0  7 NaN

# %%
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  4.0  5.0  7 NaN
# 2  NaN  4.0  2 NaN

# %%
df.ffill()
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  4.0  5.0  7 NaN
# 2  4.0  4.0  2 NaN

# %%
df.bfill()
# Out:
#      0    1  2   3
# 0  1.0  5.0  2 NaN
# 1  4.0  5.0  7 NaN
# 2  NaN  4.0  2 NaN

# %%
df=pd.DataFrame([[1,np.nan,2,None],[np.nan,5,6,7]], columns = list('ABCD'))
df
# Out:
#      A    B  C    D
# 0  1.0  NaN  2  NaN
# 1  NaN  5.0  6  7.0

# %%
values = {'A': 1, 'B': 88, 'C':-5, 'D': 99}
df.fillna(value=values)
# Out:
#      A     B  C     D
# 0  1.0  88.0  2  99.0
# 1  1.0   5.0  6   7.0

# %%
df
# Out:
#      A    B  C    D
# 0  1.0  NaN  2  NaN
# 1  NaN  5.0  6  7.0

# %%
df.interpolate(axis=1)
# Out:
#      A    B    C    D
# 0  1.0  1.5  2.0  2.0
# 1  NaN  5.0  6.0  7.0
