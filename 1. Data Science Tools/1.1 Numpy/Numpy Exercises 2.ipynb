# %% [markdown]
# # numpy exercises

# %% [markdown]
# #### 1. Import the numpy package under the name `np`

# %% [markdown]
# #### 2. Create a null vector of size 10.

# %% [markdown]
# #### 3. Print the memory size of an array.

# %% [markdown]
# #### 4. Create a null vector of size 10 but the fifth value should be 1.

# %% [markdown]
# #### 5. Create a vector with values ranging from 10 to 49.

# %% [markdown]
# #### 6. Reverse a vector (first element becomes last).

# %% [markdown]
# #### 7. Create a 3x3 matrix with values ranging from 0 to 8.

# %% [markdown]
# #### 8. Find indices of non-zero elements from [1,2,0,0,4,0].

# %% [markdown]
# #### 9. Create a 3x3 identity matrix.

# %% [markdown]
# #### 10. Create a 3x3x3 array with random values.

# %% [markdown]
# #### 11. Create a 10x10 array with random values and find the minimum and maximum values.

# %% [markdown]
# #### 12. Create a random vector of size 30 and find the mean value.

# %% [markdown]
# #### 13. Create a 2d array with 1 on the border and 0 inside.

# %% [markdown]
# #### 14. Add a border (filled with 0's) around an existing array.

# %% [markdown]
# #### 15. Create a 5x5 matrix with values 1,2,3,4 just below the diagonal.

# %% [markdown]
# #### 16. Consider a (6,7,8) shape array, what is the index (x,y,z) of the 100th element?

# %% [markdown]
# #### 17. Create a checkerboard 8x8 matrix using the tile function.

# %% [markdown]
# #### 18. Normalize a 5x5 random matrix.

# %% [markdown]
# #### 19. Multiply a 5x3 matrix by a 3x2 matrix (real matrix product).

# %% [markdown]
# #### 20. Given a 1D array, negate all elements which are between 3 and 8, in place.

# %% [markdown]
# #### 21. Round away from zero a float array (both positive and negative numbers).

# %% [markdown]
# #### 22. Find common values between two arrays.

# %% [markdown]
# #### 23. Print the dates of yesterday, today and tomorrow.

# %% [markdown]
# #### 24. Extract the integer part of a random array of positive numbers using 4 different methods.

# %% [markdown]
# #### 25. Create a 5x5 matrix with row values ranging from 0 to 4.

# %% [markdown]
# #### 26. Create a vector of size 10 with values ranging from 0 to 1, both excluded.

# %% [markdown]
# #### 27. Create a random vector of size 10 and sort it.

# %% [markdown]
# #### 28. Check if two random arrays A and B are equal.

# %% [markdown]
# #### 29. Make an array immutable (read-only).

# %% [markdown]
# #### 30. Consider a random 10x2 matrix representing cartesian coordinates, convert them to polar coordinates.
