# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# 1. Create a plot of X versus the exponential of X (np.exp(X))

# %% [raw]
# 2. Create an empty subplot with 2 rows and 2 columns (4 subplots total)

# %% [raw]
# 3. Create six plots in the same figure, using a two column and three column configuration. Plot np.sin(x) and np.cos(x) or any custom function in these plots.

# %% [raw]
# 4. Create a figure with 2 rows, 2 columns and figsize of (10, 5)
# - Plot X versus X/2 on the top left axis
# - Plot a scatter plot of 10 random numbers on the top right subplot
# - Plot a bar graph of your favourite food keys and values on the bottom left subplot
# - Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot

# %% [raw]
# 5. Create a Python dictionary with 3 of your favourite cars: the keys of the dictionary should be the car names and the values should be their prices.
# - Create a bar graph where the x-axis is the keys of the dictionary and the y-axis is the values of the dictionary
# - Add a title, xlabel and ylabel to the plot

# %% [raw]
# 6. Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to X and plot a histogram for X.

# %% [raw]
# 7. With the following example data, use 'fill_between' to fill regions between these lines in different combinations. Fill between y1 and y2, between y2 and y3, and between y1 and y3. For each area use a different color and use a good alpha (by trial and errors) to make all areas visible.
#
# x  = np.linspace(0, 3, 200)
# y1 = x ** 2 + 5
# y2 = np.exp(x) -5
# y3 = np.cos(2*x-2)

# %% [raw]
# 8. Using np.random.normal with different centers and std, show on the same plot 10 different distributions. Each distribution should have at least 2048 samples and you should use 100 bins.

# %% [raw]
# 9. Plot the typical saddle function (z = x^2 − y^2) in a three dimensional plot.
