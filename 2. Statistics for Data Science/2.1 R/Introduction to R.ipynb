# %%
5+2
5/8
5-3
# Out:
# [1] 7
# [1] 0.625
# [1] 2

# %%
x = 5 # Comment
print(x)
# Out:
# [1] 5

# %% [markdown]
# μ

# %%
x <- 5 # asignación
print(x)
# Out:
# [1] 5

# %%
edades <- c(15,20,30)
edades
edades[1:2]
edades[-1]
x2 <- edades[-1]
x2
# Out:
# [1] 15 20 30
# [1] 15 20
# [1] 20 30
# [1] 20 30

# %%
edades<25
# Out:
# [1]  TRUE  TRUE FALSE

# %%
estatura <- c(170, 158, 169)
estatura
# Out:
# [1] 170 158 169

# %%
cbind(edades, estatura)
rbind(edades, estatura)
# Out:
#      edades estatura
# [1,] 15     170
# [2,] 20     158
# [3,] 30     169
#          [,1] [,2] [,3]
# edades    15   20   30
# estatura 170  158  169

# %%
marco1 <- data.frame(Edades = edades, Estatura = estatura)
marco1
# Out:
#   Edades Estatura
# 1 15     170
# 2 20     158
# 3 30     169

# %%
marco1["Edades"]
# Out:
#   Edades
# 1 15
# 2 20
# 3 30

# %%
marco1$Estatura
# Out:
# [1] 170 158 169

# %%
dim(marco1)
# Out:
# [1] 3 2

# %%
dim(marco1["Edades"])
# Out:
# [1] 3 1

# %%
length(marco1$Edades)
# Out:
# [1] 3

# %%
marco1[1,1]
# Out:
# [1] 15

# %%
marco1[1,]
# Out:
#   Edades Estatura
# 1 15     170

# %%
marco1[,1]
# Out:
# [1] 15 20 30

# %%
marco1[2:3,1]
# Out:
# [1] 20 30

# %%
marco1[2:3,-1]
# Out:
# [1] 158 169

# %%
install.packages("readxl")
library(readxl)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
matriz1 <- matrix(c(15,170,20,158,30,169), ncol = 2, byrow = TRUE)
matriz1
# Out:
#      [,1] [,2]
# [1,] 15   170
# [2,] 20   158
# [3,] 30   169

# %%
matriz2 <- matrix(c("Juan", "Pedro", "Luis", "Pablo"), ncol = 2, byrow = TRUE)
matriz2
# Out:
#      [,1] [,2]
# [1,] Juan Pedro
# [2,] Luis Pablo

# %%
marco2 <- data.frame(Nombres = c("Juan", "Pedro", "Luis", "Pablo"), Edades = c(15,23,18,30))
marco2
marco2["Nombres"]
# Out:
#   Nombres Edades
# 1 Juan    15
# 2 Pedro   23
# 3 Luis    18
# 4 Pablo   30
#   Nombres
# 1 Juan
# 2 Pedro
# 3 Luis
# 4 Pablo

# %%
sum(marco2["Edades"])
# Out:
# [1] 86

# %%
summary(marco2)
# Out:
#    Nombres              Edades
#  Length:4           Min.   :15.00
#  Class :character   1st Qu.:17.25
#  Mode  :character   Median :20.50
#                     Mean   :21.50
#                     3rd Qu.:24.75
#                     Max.   :30.00

# %%
matriz3 <- matrix(c(15,170,20,158,30,169,25), ncol = 2, byrow = TRUE)
matriz3
# Out:
# Warning message in matrix(c(15, 170, 20, 158, 30, 169, 25), ncol = 2, byrow = TRUE):
# “data length [7] is not a sub-multiple or multiple of the number of rows [4]”
#      [,1] [,2]
# [1,] 15   170
# [2,] 20   158
# [3,] 30   169
# [4,] 25    15

# %%
matriz4 <- matrix(c(15,170,20,158,30,169,25,"Hector"), ncol = 2, byrow = TRUE)
matriz4
matriz4[,1]
# Out:
#      [,1] [,2]
# [1,] 15   170
# [2,] 20   158
# [3,] 30   169
# [4,] 25   Hector
# [1] "15" "20" "30" "25"

# %%
sum(as.numeric(matriz4[,2]), na.rm = TRUE)
mean(as.numeric(matriz4[,2]), na.rm = TRUE)
# Out:
# Warning message:
# “NAs introduced by coercion”
# [1] 497
# Warning message in mean(as.numeric(matriz4[, 2]), na.rm = TRUE):
# “NAs introduced by coercion”
# [1] 165.6667
